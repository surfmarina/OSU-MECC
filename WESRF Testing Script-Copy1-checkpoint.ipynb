# %%
from mhkit import wave
import matplotlib.pyplot as plt 
import datetime as dt
from mhkit import qc
import pandas as pd 
import numpy as np

# %%
# Station 46002 (LLNR 765.1) - WEST OREGON - 275NM West of Coos Bay, OR 
f = np.linspace(0.01,1,500)
Hs = 3
Tp = 4
data = wave.resource.jonswap_spectrum(f, Tp, Hs, gamma=3.3) 
data.plot(xlabel='frequency [Hz]', ylabel = 'response[m^2/Hz]')
# elevation = mhkit.wave.resource.surface_elevation(S, time_index, seed=None, frequency_bins=None, phases=None)
# Out:
# <AxesSubplot:xlabel='frequency [Hz]', ylabel='response[m^2/Hz]'>

# %%
# Station 46002 (LLNR 765.1) - WEST OREGON - 275NM West of Coos Bay, OR
Hs = 0.75
Tp = 6
